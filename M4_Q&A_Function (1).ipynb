# %% [markdown]
# # Theory Questions

# %%
#2. Function that accepts a string and returns its reverse

text = "PWSKILLS"
reverse = ''.join(map(lambda i: text[-i], range(1, len(text)+1)))
print(reverse)
# Out:
# SLLIKSWP

# %%
#1. Python function to return sum of all even numbers in a list



numbers = [1, 2, 3, 4, 5, 6]
sum_even = sum(filter(lambda x: x % 2 == 0, numbers))
print(sum_even)
# Out:
# 12

# %%
# 3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.


numbers = [1, 2, 3, 4]
squares = list(map(lambda x: x**2, numbers))
print(squares)
# Out:
# [1, 4, 9, 16]

# %%
# 4. Write a Python function that checks if a given number is prime or not from 1 to 200


is_prime = lambda n: n > 1 and all(n % i != 0 for i in range(2, int(n**0.5)+1))
print(is_prime(17))
print(is_prime(100))
# Out:
# True
# False

# %%
# 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of  terms


class Fibonacci:
    def __init__(self, n):
        self.n = n
        self.a, self.b = 0, 1
        self.count = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.count >= self.n:
            raise StopIteration
        self.count += 1
        self.a, self.b = self.b, self.a + self.b
        return self.a

for num in Fibonacci(7):
    print(num)
# Out:
# 1
# 1
# 2
# 3
# 5
# 8
# 13

# %%
# 6. Write a generator function in Python that yields the powers of 2 up to a given exponent

def powers_of_two(n):
    for i in range(n + 1):
        yield 2 ** i

# Example usage
for val in powers_of_two(10):
    print(val)
# Out:
# 1
# 2
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 1024

# %%
# 7. Implement a generator function that reads a file line by line and yields each line as a string.

def read_file_lines(filename):
    with open(filename, 'r') as file:
        for line in file:
            yield line.strip()

for line in read_file_lines('sample.txt'):
    print(line)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-4131398721.py in <cell line: 0>()
#       6             yield line.strip()
#       7
# ----> 8 for line in read_file_lines('sample.txt'):
#       9     print(line)
#
# /tmp/ipython-input-4131398721.py in read_file_lines(filename)
#       2
#       3 def read_file_lines(filename):
# ----> 4     with open(filename, 'r') as file:
#       5         for line in file:
#       6             yield line.strip()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample.txt'

# %%
# 8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple


data = [(1, 'apple'), (2, 'banana'), (3, 'cherry')]
sorted_data = sorted(data, key=lambda x: x[1])
print(sorted_data)

# %%
# 9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit


celsius = [0, 20, 30, 40]
fahrenheit = list(map(lambda c: (c * 9/5) + 32, celsius))
print(fahrenheit)

# %%
# 10. Create a Python program that uses `filter()` to remove all the vowels from a given string


text = "Hello World"
vowels = "aeiouAEIOU"
result = ''.join(filter(lambda ch: ch not in vowels, text))
print(result)

# %%
# 11) Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this


orders = [
    [34587, "Learning Python, Mark Lutz", 3, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]


result = list(map(lambda order: (
    order[0],
    order[2] * order[3] + (10 if order[2] * order[3] < 100 else 0)
), orders))

print(result)

# %% [markdown]
# # Practical Questions

# %%
#11. Internal mechanism of sum using reduce()
    # Reduce() applies a function cumulatively to elements. For [47,11,42,13], it works like:

from functools import reduce
nums = [47, 11, 42, 13]
print(reduce(lambda x, y: x + y, nums))

# %%
#10. Difference between map(), reduce(), and filter()
  #map() transforms each element. filter() selects elements based on a condition, reduce() combines elements into a single value.
from functools import reduce
nums=[1,2,3,4]
print(list(map(lambda x:x*2, nums)))
print(list(filter(lambda x:x%2==0, nums)))
print(reduce(lambda x,y: x+y, nums))

# %%
#9. Purpose and usage of map() function
  #map() applies a function to each item in an iterable and returns a map object.

nums=[1,2,3]
squared=map(lambda x: x**3, nums)
print(list(squared))

# %%
#8. What is a lambda function and when is it used?
  #lambda function is a small anonymous function used for short operations without defining a full function.


square = lambda x: x**2
print(square(5))

# %%
#7. Advantages of generators over regular functions
  #Generators save memory because they produce items lazily instead of storing all at once.

def big_gen():
    for i in range(8732800):
        yield i

# %%
#6. Concept of generators and how they are defined
  #Generators are special functions that yield values one at a time using yield, making them memory-efficient.


def gen_nums():
    for i in range(3):
        yield i

for num in gen_nums():
    print(num)

# %%
#5.What are iterators and how do they differ from iterables?
  #An iterable is any object you can loop over (like list, tuple), while an iterator is an object that produces elements one at a time using __next__().

nums = [1, 2, 3]  # Iterable
it = iter(nums)   # Iterator
print(next(it))

# %%
#4. Purpose of return statement
  #Return sends a value back to the caller from a function, allowing further use of that result.

def add(a, b):
    return a + b
result = add(2, 3)
print(result)

# %%
#3. Different ways to define and call a function
#Define a function using def or lambda, and call it by its name with parentheses.


def greet():
    print("Hello")
greet()
square = lambda x: x**3
print(square(9))

# %%
#2. Concept of function arguments and parameters
  #Parameters are variables defined in a function to accept input, while arguments are actual values passed when calling the function.


def add(a, b):
    return a + b
result = add(5, 3)
print(result)

# %%
#1. Difference between a function and a method in Python
  #A function is a block of code that performs a task and can be called independently, while a method is a function that belongs to an object and is called on that object.

def greet():  # Function
    print("Hello")

name = "Python"
print(name.upper())
