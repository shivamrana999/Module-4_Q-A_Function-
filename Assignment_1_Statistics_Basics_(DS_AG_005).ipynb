# %%
# Q1 What is the difference between descriptive statistics and inferential statistics? Explain with examples.
•	Descriptive statistics: Summarize and describe data.
Example: Average marks of a class, median income of a city.
•	Inferential statistics: Make predictions or generalizations about a population using sample data.
Example: Predicting election results based on a survey of 1,000 voters.

# %%
# Q2: What is sampling in statistics? Explain the differences between random and stratified sampling.
•	Sampling: Selecting a subset of data from a population to analyze.
•	Random sampling: Every individual has equal chance of selection. Example: Lottery draw.
•	Stratified sampling: Population divided into groups (strata), then samples taken proportionally. Example: Sampling students by grade level.

# %%
# Q3: Define mean, median, and mode. Explain why these measures of central tendency are important.
•	Mean: Average value.
•	Median: Middle value when data is sorted.
•	Mode: Most frequent value.
•	These measures show the "center" of data, helping understand typical values.

# %%
# Q4: Explain skewness and kurtosis. What does a positive skew imply about the data?
•	Skewness: Measures asymmetry of data distribution.
o	Positive skew → Tail on the right, data concentrated on the left (e.g., income distribution).
•	Kurtosis: Measures "peakedness" of distribution.
•	High kurtosis → More outliers.

# %%
# Q5  Implement a Python program to compute the mean, median, and mode of a given list of numbers.

number = [12, 15, 12, 18, 19, 12, 20, 22, 19, 19, 24, 24, 24, 26, 28]
import statistics as Stats
mean_value = Stats.mean(number)
median_value = Stats.median(number)
mode_value = Stats.mode(number)

print("mean:", mean_value)
print("median:", median_value)
print("mode:", mode_value)
# Out:
# mean: 19.6
# median: 19
# mode: 12

# %%
# Q6 Compute the covariance and correlation coefficient between the following two datasets provided as lists in Python:
list_x = [10, 20, 30, 40, 50]
list_y = [15, 25, 35, 45, 60]
import numpy as np

cov_matrix =np.cov(list_x, list_y)
corr_matrix = np.corrcoef(list_x, list_y)

print("Covariance Matrix:", cov_matrix)
print("Correlation Matrix:", corr_matrix)
# Out:
# Covariance Matrix: [[250. 275.]
#  [275. 305.]]
# Correlation Matrix: [[1.         0.99589321]
#  [0.99589321 1.        ]]

# %%
# Q7 Write a Python script to draw a boxplot for the following numeric list and identify its outliers. Explain the result:
data = [12, 14, 14, 15, 18, 19, 19, 21, 22, 22, 23, 23, 24, 26, 29, 35]

import matplotlib.pyplot as plt
plt.boxplot(data)
plt.title("Boxplot")
plt.show()

# %%
# Q8 You are working as a data analyst in an e-commerce company. The marketing team wants to know if there is a relationship between advertising spend and daily sales.
#● Explain how you would use covariance and correlation to explore this relationship.
#● Write Python code to compute the correlation between the two lists:
advertising_spend = [200, 250, 300, 400, 500]
daily_sales = [2200, 2450, 2750, 3200, 4000]
correlation = np.corrcoef(advertising_spend, daily_sales)[0,1]
print("Correlation:", correlation)
# Out:
# Correlation: 0.9935824101653329

# %%
#Q9 Your team has collected customer satisfaction survey data on a scale of 1-10 and wants to understand its distribution before launching a new product.
#● Explain which summary statistics and visualizations (e.g. mean, standard deviation, histogram) you’d use.
#● Write Python code to create a histogram using Matplotlib for the survey data:
survey_scores = [7, 8, 5, 9, 6, 7, 8, 9, 10, 4, 7, 6, 9, 8, 7]
mean_val = np.mean(survey_scores)
std_dev = np.std(survey_scores)

print("Mean:", mean_val)
print("Standard Deviation:", std_dev)

plt.hist(survey_scores, bins=6, edgecolor='black')
plt.title("Survey Score Distribution")
plt.xlabel("Scores")
plt.ylabel("Frequency")
plt.show()
# Out:
# Mean: 7.333333333333333
# Standard Deviation: 1.577621275493231
